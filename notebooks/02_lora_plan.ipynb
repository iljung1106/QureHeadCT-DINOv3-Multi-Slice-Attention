# %% [markdown]
# # LoRA Fine-tuning Plan
#
# This notebook is a placeholder for the main model after the frozen baseline is validated.
#
# Planned model:
#
# ```text
# DINOv3 + LoRA -> slice embeddings -> BiGRU -> Gated ABMIL -> scan logits
#                 -> optional slice auxiliary head -> slice logits
# ```
#
# Important rule: the slice auxiliary loss should be applied only to samples with true slice-level labels. Do not copy scan labels onto every slice as if they were slice labels.

# %%
import torch
print('cuda:', torch.cuda.is_available())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
